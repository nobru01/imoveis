# %%
import pandas as pd
import tabula

# %%
df=tabula.read_pdf('./Balancetes/11355_H-312-S_Balancete_2022-06-20-12-35-07.pdf',pages='3')

# %%
df  # Não deu resultado
# Out:
# [                                           Unnamed: 0 Unnamed: 1  \
#  0                    DESPESAS ORDINÁRIAS - MANUTENÇÃO        NaN
#  1   CAESB - CAESB - Pagto. consumo no mês 05/2022,...    05/2022
#  2   CEB - Neoenergia - Energia Elétrica - Pagto. c...    05/2022
#  3                             05/2022, Inscr. 9030-1.        NaN
#  4   Material/Serviços Elétrico/Hidraulica - Ferros...    05/2022
#  5   aquisição de material hidráulico para o jardim...        NaN
#  6   Material/Serviços Elétrico/Hidraulica - Ferros...    05/2022
#  7   aquisição de material hidráulico para o jardim...        NaN
#  8   Material/Serviços Elétrico/Hidraulica - Sarkis...    05/2022
#  9   aquisição de material elétrico para o condomínio.        NaN
#  10  Material/Serviços Elétrico/Hidraulica - Sarkis...    05/2022
#  11  aquisição de material elétrico para o condomín...        NaN
#  12  Manutenção de Elevadores - Thyssenkrupp Elevad...    04/2022
# ...
